# %% [markdown]
# <a href="https://colab.research.google.com/github/WHOpsAnalyticsTeam/f_detection_colab/blob/master/Fraud_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# FROM HERE WE NEED TO UPLOAD THE FILE THAT WILL BE PROCESSED IN THIS CASE THE CPT CODES FILE

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-57fa7236-4d5a-4a1c-b51f-a8b1ddfc11ad" name="files[]" multiple disabled />
#      <output id="result-57fa7236-4d5a-4a1c-b51f-a8b1ddfc11ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving MORE_CPT_STUFF_BY_POI.xlsx to MORE_CPT_STUFF_BY_POI.xlsx

# %%
import numpy as np
import pandas as pd
import sklearn
import io
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
cpt_ds = pd.read_excel(io.BytesIO(uploaded['MORE_CPT_STUFF_BY_POI.xlsx']))

# %%
cpt_ds = cpt_ds.replace(np.nan,0)

# %% [markdown]
# FROM THIS POINT WE ARE ARRANGING THE DATASET TO HAVE IT READY FOR THE CLUSTERING ALGORITHM

# %%
cpt_ds.columns = cpt_ds.iloc[0]
cpt_ds = cpt_ds.drop(index=0)

# %%
cpt_ds1 = cpt_ds

# %%
cpt_ds1 = cpt_ds1.drop(index=272)
cpt_ds1['mean'] = cpt_ds1.mean(axis=1)
cpt_ds1
# Out:
# 0               Providers  97010.0  97035.0  ...  99407.0  Grand Total        mean
# 1    PALMETTOHEALTHMEDICA   8636.0   6730.0  ...      0.0        64718  328.205556
# 2    ULTRACARE&DIAGNOSTIC   8500.0   8577.0  ...      0.0        71880  369.627778
# 3    WELLNESSHEALTHCARECL   5079.0   6371.0  ...      0.0        42338  187.077778
# 4    THERIGHTSPINALCLINIC   3558.0   4227.0  ...      0.0        37232  181.277778
# 5    EXCELLENTHEALTHSOLUT   2584.0   2536.0  ...      0.0        19795  104.238889
# ..                    ...      ...      ...  ...      ...          ...         ...
# 267  AlternativeMedicalCe      0.0      0.0  ...      0.0         6150   27.655556
# 268  NewHorizonMedical&Di      0.0     92.0  ...      0.0         2059    9.605556
# 269   AjTherapyOfTampaInc      0.0      0.0  ...      0.0            1    0.005556
# 270    CONTEXMEDICALGROUP      0.0      0.0  ...      0.0            1    0.005556
# 271  ALVAREZTERAPEUTICCEN      0.0     10.0  ...      0.0          100    0.555556
#
# [271 rows x 244 columns]

# %%
usage_ds = cpt_ds1.describe()

# %%
usage_ds
# Out:
# 0          97010.0      97035.0  ...     99407.0        mean
# count   271.000000   271.000000  ...  271.000000  271.000000
# mean    426.070111   403.184502  ...    0.003690   18.947622
# std     939.684777   918.038163  ...    0.060746   38.188541
# min       0.000000     0.000000  ...    0.000000    0.000000
# 25%       8.000000     4.500000  ...    0.000000    0.372222
# 50%      71.000000    46.000000  ...    0.000000    6.377778
# 75%     538.500000   486.000000  ...    0.000000   24.522222
# max    8636.000000  8577.000000  ...    1.000000  369.627778
#
# [8 rows x 181 columns]

# %% [markdown]
#   ITERATING OVER DATASET COLUMNS (CPT CODES) TO CLUSTER BY USAGE BASED ON AVERAGE AND GETTING NUMBER OF CLUSTERS

# %%
def getClusters(av):
  if av > 350:
    return 1;
  elif av > 250:
    return 2;
  elif av > 100:
    return 3;
  elif av < 100:
    return 4;

# %%
#THIS IS A GROUPING FUNCTION BY REPETITIONS IN EVERY LINE
#class_counts = cpt_ds1.groupby(97112.0).size()
#class_counts

# %% [markdown]
# CREATE ARRAY WITH ONLY THE "MEAN" VALUES TO PLOT USAGE BY CPT CODE

# %%
avg_array = [];
for i,j in usage_ds.iterrows():
  if i == "mean":
    i = 0;
    avg_array.insert(i,j);

# %%
avg_df = pd.DataFrame(avg_array);
avg_df
# Out:
# 0        97010.0     97035.0     97140.0  ...  81001.0  99407.0       mean
# mean  426.070111  403.184502  374.892989  ...  0.00369  0.00369  18.947622
#
# [1 rows x 181 columns]

# %%
#usage_ds.plot.pie(y='mean',figsize=(5,5))
avg_df1 = avg_df.T;
avg_df1
# Out:
#                mean
# 0
# 97010.0  426.070111
# 97035.0  403.184502
# 97140.0  374.892989
# 97112.0  373.752768
# 97110.0  370.918819
# ...             ...
# 76770.0    0.003690
# 81000.0    0.003690
# 81001.0    0.003690
# 99407.0    0.003690
# mean      18.947622
#
# [181 rows x 1 columns]
